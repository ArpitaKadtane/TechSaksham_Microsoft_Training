# %%
#Panda Data
import pandas as pd

# %%
import numpy as np

# %%
# numpy 
"""
2-scalar 
[1,2,3]-vector
[[1,2],[3,4]]- matrix
"""
#pandas 
"""
1d -series -homogenous array,size-immutable
2d-dataframe -heterogenously types columns,size-mutable
"""
# Out:
# '\n1d -series -homogenous array,size-immutable\n2d-dataframe -heterogenously types columns,size-mutable\n'

# %%
#pandas.Series(data,index,dtype)

# %% [markdown]
# Pandas

# %%
series1=pd.Series([1,2,3,4,5], index=["a","b","c","d","e"])
print(series1)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
for i in series1:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Creating Serires using numpy

# %%
series2=pd.Series(np.random.randn(5),
                  index=["a","b","c","d","e"])
print(series2)
# Out:
# a   -0.883533
# b   -1.389016
# c   -0.182991
# d    0.178989
# e    0.114177
# dtype: float64

# %%
dictionary={"a":1, "b":2, "c":3}
d1=pd.Series(dictionary)
d1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
#[]- series
#[[]]- dataframe

# %%
#d1[[1,2]]
d1.iloc[[1,2]]
# Out:
# b    2
# c    3
# dtype: int64

# %%
series1+series2
# Out:
# a    0.116467
# b    0.610984
# c    2.817009
# d    4.178989
# e    5.114177
# dtype: float64

# %%
series+series1
# Out:
# a     2
# b     4
# c     6
# d     8
# e    10
# dtype: int64

# %%
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame(columns=['c1','c2','c3'])
print(df)
# Out:
# Empty DataFrame
# Columns: [c1, c2, c3]
# Index: []

# %%
df=pd.DataFrame(columns=['c1','c2','c3','c4'],
                index=range(1,6))
print(df)
# Out:
#     c1   c2   c3   c4
# 1  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN

# %%
dictionary ={'a':1, 'b':2,'c':3}
pd.DataFrame([dictionary])
# Out:
#    a  b  c
# 0  1  2  3

# %%
df.index
# Out:
# RangeIndex(start=1, stop=6, step=1)

# %%
df.columns
# Out:
# Index(['c1', 'c2', 'c3', 'c4'], dtype='object')

# %% [markdown]
# Create a DataFrame using list

# %%
mylist=[
    ['Apple','Red'],
    ['Banana','yellow'],
    ['Orange','orange']
]

mydata=pd.DataFrame(mylist)
mydata
# Out:
#         0       1
# 0   Apple     Red
# 1  Banana  yellow
# 2  Orange  orange

# %%
mydata=pd.DataFrame(mylist,columns=['Fruit_name','column_name'])
mydata
# Out:
#   Fruit_name column_name
# 0      Apple         Red
# 1     Banana      yellow
# 2     Orange      orange

# %% [markdown]
# DataFrame using numpy array

# %%
mylist1=np.array([
    [0,1],
    [2,3],
    [4,5]
])
mydf=pd.DataFrame(mylist1, columns=["Even","odd"])
mydf
# Out:
#    Even  odd
# 0     0    1
# 1     2    3
# 2     4    5

# %% [markdown]
# load a csv data using pandas

# %%
df=pd.read_csv('cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.set_index('name') #it will return a new dataframe
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %% [markdown]
# Examining in the dataframe

# %%
df.head()
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
df.tail()
# Out:
#                       name  calories  protein  vitamins     rating
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df.describe()
# Out:
#          calories    protein   vitamins     rating
# count   10.000000  10.000000  10.000000  10.000000
# mean    95.000000   2.900000  22.500000  49.205817
# std     25.495098   0.875595   7.905694  20.315297
# min     50.000000   2.000000   0.000000  29.509541
# 25%     75.000000   2.000000  25.000000  34.083970
# 50%    100.000000   3.000000  25.000000  43.079408
# 75%    110.000000   3.750000  25.000000  57.897582
# max    130.000000   4.000000  25.000000  93.704912

# %% [markdown]
# slicing rows using the bracket operators

# %%
df[1:4]
# Out:
#                         name  calories  protein  vitamins     rating
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df[['calories','rating']] #cannot do slice indexing on type str
# Out:
#    calories     rating
# 0        70  68.402973
# 1       120  33.983679
# 2        70  59.425505
# 3        50  93.704912
# 4       110  34.384843
# 5       110  29.509541
# 6       110  33.174094
# 7       130  37.038562
# 8        90  49.120253
# 9        90  53.313813

# %% [markdown]
# Boolean Filter

# %%
df1=df[0:5]
boolean_list=[True, False, True, True, False]
df1[boolean_list]
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df['calories']>70
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: calories, dtype: bool

# %%
condition=df['calories']>70
df[condition]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %% [markdown]
# filtering rows using &(and) and|(or) operators

# %%
df[(df['calories']>70) & (df['protein']<3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 8                Bran Chex        90        2        25  49.120253

# %%
df[(df['calories']>70) | (df['protein']<3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %% [markdown]
# Filtering data using loc()

# %%
df.loc[2,'protein']
# Out:
# np.int64(4)

# %%
df.loc[0:4, ['protein','name']]
# Out:
#    protein                       name
# 0        4                  100% Bran
# 1        3          100% Natural Bran
# 2        4                   All-Bran
# 3        4  All-Bran with Extra Fiber
# 4        2             Almond Delight

# %%
df.iloc[0:5,0:3]
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %% [markdown]
# indexing and slicing

# %%
df.iloc[[0,2,4],0:3]
# Out:
#              name  calories  protein
# 0       100% Bran        70        4
# 2        All-Bran        70        4
# 4  Almond Delight       110        2

# %% [markdown]
# Adding and deleting rows and columns

# %%
#it will update the original dataframe
df1.loc[4]=['Arpita',110,1,25,27.75]
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     Arpita       110        1        25  27.750000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %% [markdown]
# Change made in df1 will also affect df dataset

# %%
df1=df.iloc[0:5].copy()
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     Arpita       110        1        25  27.750000

# %%
df1.drop(3,axis=0,inplace=True)
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
# 4             Arpita       110        1        25  27.750000

# %%
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     Arpita       110        1        25  27.750000

# %%
# to delete the column using column name.
df1.drop("name",axis=1)
# Out:
#    calories  protein  vitamins     rating
# 0        70        4        25  68.402973
# 1       120        3         0  33.983679
# 2        70        4        25  59.425505
# 3        50        4        25  93.704912
# 4       110        1        25  27.750000

# %%
df1['My new column']=[1,2,3,4,5]
df1
# Out:
#                         name  calories  protein  vitamins     rating  \
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     Arpita       110        1        25  27.750000
#
#    My new column
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
assending_df=df.sort_values(by='calories') # assending order
assending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 4                     Arpita       110        1        25  27.750000
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562

# %%
descending_df=df.sort_values(by='calories',ascending =False)
descending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 7                    Basic 4       130        3        25  37.038562
# 1          100% Natural Bran       120        3         0  33.983679
# 6                Apple Jacks       110        2        25  33.174094
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 4                     Arpita       110        1        25  27.750000
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df.columns=['col1','col2','col3','col4','col5']
df
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                     Arpita   110     1    25  27.750000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %%
df.to_csv('myfile.csv', index_label=False)

# %%
newdf=pd.read_csv('myfile.csv')
newdf
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                     Arpita   110     1    25  27.750000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %% [markdown]
# concatination dataframes

# %%
df2=df[5:8].copy()
df2
# Out:
#                       col1  col2  col3  col4       col5
# 5  Apple Cinnamon Cheerios   110     2    25  29.509541
# 6              Apple Jacks   110     2    25  33.174094
# 7                  Basic 4   130     3    25  37.038562

# %%
df2=df2.reset_index(drop=True)
df2
# Out:
#                       col1  col2  col3  col4       col5
# 0  Apple Cinnamon Cheerios   110     2    25  29.509541
# 1              Apple Jacks   110     2    25  33.174094
# 2                  Basic 4   130     3    25  37.038562

# %%
df1.drop("My new column", axis=1, inplace=True)

# %%
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     Arpita       110        1        25  27.750000

# %%
pd.concat([df,df1], ignore_index=True)
#pd.concat([df,df1])
# Out:
#                          col1   col2  col3  col4       col5  \
# 0                   100% Bran   70.0   4.0  25.0  68.402973
# 1           100% Natural Bran  120.0   3.0   0.0  33.983679
# 2                    All-Bran   70.0   4.0  25.0  59.425505
# 3   All-Bran with Extra Fiber   50.0   4.0  25.0  93.704912
# 4                      Arpita  110.0   1.0  25.0  27.750000
# 5     Apple Cinnamon Cheerios  110.0   2.0  25.0  29.509541
# 6                 Apple Jacks  110.0   2.0  25.0  33.174094
# 7                     Basic 4  130.0   3.0  25.0  37.038562
# 8                   Bran Chex   90.0   2.0  25.0  49.120253
# 9                 Bran Flakes   90.0   3.0  25.0  53.313813
# 10                        NaN    NaN   NaN   NaN        NaN
# 11                        NaN    NaN   NaN   NaN        NaN
# 12                        NaN    NaN   NaN   NaN        NaN
# 13                        NaN    NaN   NaN   NaN        NaN
# 14                        NaN    NaN   NaN   NaN        NaN
#
# ...

# %% [markdown]
# groupby

# %%
data={"gender":["female","male","female","male"], "Score":[86,89,67,90]}

new_df=pd.DataFrame(data)
new_df
# Out:
#    gender  Score
# 0  female     86
# 1    male     89
# 2  female     67
# 3    male     90

# %%
group= new_df.groupby(new_df['gender']).mean()
group
# Out:
#         Score
# gender
# female   76.5
# male     89.5
